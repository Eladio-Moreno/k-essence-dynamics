# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
datos = np.loadtxt("output/test_perturbations_k2_s.dat").T
back = np.loadtxt("output/test_background.dat").T
datos1 = np.loadtxt("output/test_perturbations_k1_s.dat").T
datos2 = np.loadtxt("output/test_perturbations_k0_s.dat").T

# %%
per = np.loadtxt("output/test_tk.dat").T

# %%
lcdm = np.loadtxt("output/explanatory06_perturbations_k2_s.dat").T

# %%
z=back[0]
a=1/(1+z)

# %%
len(a)
# Out:
# 4620

# %%
#plt.plot(datos[12])
plt.xscale('log')
plt.yscale('log')
plt.plot(lcdm[0],abs(lcdm[15]),label=r"$\delta_{cdm}$")
plt.plot(lcdm[0],abs(lcdm[8]),label=r"$\delta_b$")
#plt.plot(lcdm[0],abs(lcdm[12]),label=r"$\delta_{ur}$")
plt.plot(lcdm[0],abs(lcdm[2]),label=r"$\delta_{\gamma}$")


plt.xlim(1,lcdm[0][-1])
plt.ylim(0.1,10e2)

plt.legend()
plt.show()

# %%
plt.xscale('log')
plt.yscale('log')
#plt.plot(lcdm[0],abs(lcdm[15]),label=r"$\delta_{cdm}$")

plt.plot(datos1[0],abs(datos1[8]),label=r"$\delta_b$")
plt.plot(datos1[0],abs(datos1[2]),label=r"$\delta_\gamma$")

#plt.plot(datos[0],abs(datos[12]),label=r"$\delta_{ur}$")
#plt.plot(datos[0],abs(datos[15]))
#plt.plot(datos[0],abs(datos[16]))
plt.ylim(0.1,10e2)
plt.xlim(1,datos1[0][-1])
plt.legend()

# %%
plt.xscale('log')
plt.yscale('log')
#plt.plot(lcdm[0],abs(lcdm[15]),label=r"$\delta_{cdm}$")

plt.plot(datos2[0],abs(datos2[8]),label=r"$\delta_b$")
plt.plot(datos2[0],abs(datos2[2]),label=r"$\delta_\gamma$")

#plt.plot(datos[0],abs(datos[12]),label=r"$\delta_{ur}$")
#plt.plot(datos[0],abs(datos[15]))
#plt.plot(datos[0],abs(datos[16]))
plt.ylim(0.1,10e2)
plt.xlim(1,datos2[0][-1])
plt.legend()

# %%
plt.xscale('log')
plt.yscale('log')
#plt.plot(lcdm[0],abs(lcdm[15]),label=r"$\delta_{cdm}$")

plt.plot(datos[0],abs(datos[8]),label=r"$\delta_b$")
plt.plot(datos[0],abs(datos[2]),label=r"$\delta_\gamma$")

#plt.plot(datos[0],abs(datos[12]),label=r"$\delta_{ur}$")
#plt.plot(datos[0],abs(datos[15]))
#plt.plot(datos[0],abs(datos[16]))
plt.ylim(0.1,10e2)
plt.xlim(1,datos[0][-1])
plt.legend()

# %%
plt.xscale('log')
plt.yscale('log')
plt.plot(datos[0],abs(datos[15]), label="$V_X$")
plt.plot(datos[0],abs(datos[16]), label="$V^\prime_X$")
plt.legend(fontsize=15)
plt.show()

# %%
plt.xscale('log')
plt.yscale('log')
plt.plot(datos1[0],abs(datos1[15]), label="$V_X$")
plt.plot(datos1[0],abs(datos1[16]),label="$V^\prime_X$")
plt.legend(fontsize=15)
plt.show()

# %%
plt.xscale('log')
plt.yscale('log')
plt.plot(datos2[0],abs(datos2[15]))
plt.plot(datos2[0],abs(datos2[16]))

# %%
datos[0][-1]
# Out:
# 14204.488475

# %%
plt.plot(datos[8])
plt.plot(lcdm[8])

# %%
plt.plot(datos[2])
