# %%
# import classy module
from classy import Class

# %%
import matplotlib.pyplot as plt

# %%
# create instance of the class "Class"
model = Class()
# pass input parameters
model.set({'Omega_fld' : 0,
                   'Omega_smg' : -1,
                   'Omega_Lambda':0.69,# 0.572,
                   'omega_b':0.022032,
                   'Omega_cdm':0,
                   'gravity_model':'quintessence_monomial',
                   'x0_schm':1,
                   'theta_schm':1e-19,
                   'DM_schm':0.26,
                   'h_schm':2.7,
                   'V0_schm':6.2,
                   'lambda_schm':2.89e4,'h':0.67556,'A_s':2.8e-9,'n_s':0.97,'tau_reio':0.0505})
model.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
# run class
model.compute()
# Out:
# aquí voy y todo bien 2.7
# aquí voy y todo bien 2.7
# aquí voy y todo bien 2.51207
# aquí voy y todo bien 1.90403
# aquí voy y todo bien 2.20805
# aquí voy y todo bien 2.07993
# aquí voy y todo bien 2.14399
# aquí voy y todo bien 2.08008
# aquí voy y todo bien 2.08001
# aquí voy y todo bien 2.08008

# %%
# Obtener información del background (expansión, distancias, etc.)
background = model.get_background()

# %%
background[].ipynb_checkpoints/

# %%
background
# Out:
# {'z': array([1.00000000e+14, 9.93048659e+13, 9.86145640e+13, ...,
#         1.37712093e-02, 6.68663559e-03, 0.00000000e+00]),
#  'proper time [Gyr]': array([7.55309403e-26, 7.65920744e-26, 7.76681165e-26, ...,
#         1.36246913e+01, 1.37257100e+01, 1.38220180e+01]),
#  'conf. time [Mpc]': array([4.63114702e-09, 4.66388883e-09, 4.69663064e-09, ...,
#         1.41427005e+04, 1.41739896e+04, 1.42036159e+04]),
#  'H [1/Mpc]': array([2.15909120e+22, 2.12917838e+22, 2.09967997e+22, ...,
#         2.26800918e-04, 2.26046840e-04, 2.25342564e-04]),
#  'comov. dist.': array([14203.61586722, 14203.61586722, 14203.61586722, ...,
#            60.91534327,    29.62623513,     0.        ]),
#  'ang.diam.dist.': array([1.42036159e-10, 1.43030412e-10, 1.44031625e-10, ...,
#         6.00878608e+01, 2.94294511e+01, 0.00000000e+00]),
#  'lum. dist.': array([1.42036159e+18, 1.41048817e+18, 1.40068339e+18, ...,
#         6.17542212e+01, 2.98243350e+01, 0.00000000e+00]),
#  'comov.snd.hrz.': array([2.67404299e-09, 2.69276129e-09, 2.71161062e-09, ...,
#         1.23304875e+03, 1.23375063e+03, 1.23441294e+03]),
#  '(.)rho_g': array([2.75156054e+44, 2.67584646e+44, 2.60221579e+44, ...,
#         2.90628958e-12, 2.82589671e-12, 2.75156054e-12]),
#  '(.)rho_b': array([2.45139060e+33, 2.40062379e+33, 2.35090832e+33, ...,
#         2.55406754e-09, 2.50089482e-09, 2.45139060e-09]),
#  '(.)rho_lambda': array([3.50376959e-08, 3.50376959e-08, 3.50376959e-08, ...,
#         3.50376959e-08, 3.50376959e-08, 3.50376959e-08]),
#  '(.)rho_ur': array([1.90344398e+44, 1.85106733e+44, 1.80013193e+44, ...,
#         2.01048072e-12, 1.95486743e-12, 1.90344398e-12]),
#  '(.)rho_crit': array([4.66167483e+44, 4.53340056e+44, 4.40865599e+44, ...,
#         5.14386566e-08, 5.10971740e-08, 5.07792702e-08]),
#  'gr.fac. D': array([2.24623965e-17, 3.13378004e-05, 6.26756008e-05, ...,
#         9.97926341e-01, 9.98993307e-01, 1.00000000e+00]),
#  'gr.fac. f': array([2.00000000e+14, 1.43356562e+02, 7.16782808e+01, ...,
#         1.53015821e-01, 1.51741827e-01, 1.50532688e-01]),
#  '(.)rho_smg': array([6.67031591e+41, 6.48677032e+41, 6.30827531e+41, ...,
#         1.38419764e-08, 1.35538025e-08, 1.32855287e-08]),
#  '(.)p_smg': array([2.22343864e+41, 2.16225677e+41, 2.10275844e+41, ...,
#         1.08162983e-27, 1.03706208e-27, 9.96414716e-28]),
#  'M*^2_smg': array([1., 1., 1., ..., 1., 1., 1.]),
#  'D_M*^2_smg': array([0., 0., 0., ..., 0., 0., 0.]),
#  'kineticity_smg': array([1.71706080e-02, 1.71706080e-02, 1.71706080e-02, ...,
#         5.16558121e+18, 5.20010281e+18, 5.23265798e+18]),
#  'braiding_smg': array([-0., -0., -0., ..., -0., -0., -0.]),
#  'tensor_excess_smg': array([-0., -0., -0., ..., -0., -0., -0.]),
#  'Mpl_running_smg': array([0., 0., 0., ..., 0., 0., 0.]),
#  'c_s^2': array([3.33333333e-01, 3.33333333e-01, 3.33333333e-01, ...,
#         1.56282571e-19, 1.53028950e-19, 1.50000009e-19]),
#  'kin (D)': array([1.71706080e-02, 1.71706080e-02, 1.71706080e-02, ...,
#         5.16558121e+18, 5.20010281e+18, 5.23265798e+18])}

# %%
# Extraer cantidades del background
z = background['z']                    # Redshift
H_z = background['H [1/Mpc]']           # Hubble parameter H(z)
a=1/(1+z)
rho_gamma = background['(.)rho_g']
rad= rho_gamma + background['(.)rho_ur'] 
bar= background['(.)rho_b'] 
lamb= background['(.)rho_lambda'] 
rho_crit = background['(.)rho_crit'] 
rho_sch = background['(.)rho_smg']
p_sch = background['(.)p_smg']

#phi= background['phi_smg']
#X=1/2*(phi_prima/a)**2

# %%
Omega_rad=rad/rho_crit
Omega_bar=bar/rho_crit
Omega_lambda=lamb/rho_crit
Omega_sch=rho_sch/rho_crit
w=p_sch/rho_sch
w_sch = (p_sch-lamb)/(rho_sch+lamb)  
rho_rel = rad + 3*p_sch

# %%
plt.figure(figsize=(10, 7))
#plt.yscale("log")
plt.xscale("log")
plt.xlim(1e-9,1)
#plt.plot(a0,Omega_lambda0+Omega_rad0+Omega_sch0+Omega_bar0,color="green",label="Constricción de Friedmann")
plt.plot(a,Omega_rad,color="black",label="$\Omega _{\gamma}$")
plt.plot(a,Omega_bar,color="red",label="$\Omega _{b}$")
plt.plot(a,Omega_sch,"--",color="blue",label="$\Omega _{\phi DM}$")
plt.plot(a,Omega_lambda, "--", color="purple" ,label="$\Omega _{\phi DE}$")
plt.plot(a,Omega_sch + Omega_lambda, color="blue",label="$\Omega _{\phi}$")


#plt.plot(a,Omega_lambda+Omega_cdm+Omega_bar+Omega_rad,color="black",label="$\Omega _{total}$")
plt.title('Parámetros de densidad', fontsize=20)
plt.xlabel('a',fontsize=20)
plt.ylabel('$\Omega _{i}$',fontsize=20)
plt.legend(fontsize=16)

# %%
# get all C_l output
cls = model.lensed_cl(2500)
# To check the format of cls
cls.values()
# Out:
# dict_values([array([0.00000000e+00, 0.00000000e+00, 1.86804328e-10, ...,
#        5.22520391e-18, 5.20834105e-18, 5.19155217e-18]), array([0.00000000e+00, 0.00000000e+00, 2.40203009e-15, ...,
#        1.59150089e-19, 1.58635944e-19, 1.58119086e-19]), array([ 0.00000000e+00,  0.00000000e+00,  3.03621785e-13, ...,
#        -4.22105616e-19, -4.21179380e-19, -4.20248767e-19]), array([0.00000000e+00, 0.00000000e+00, 7.40097113e-19, ...,
#        4.54285984e-21, 4.53256428e-21, 4.52229809e-21]), array([0.00000000e+00, 0.00000000e+00, 1.15590558e-08, ...,
#        2.36576893e-22, 2.35941376e-22, 2.35307755e-22]), array([0.00000000e+00, 0.00000000e+00, 6.29577005e-10, ...,
#        6.17260510e-23, 6.15750424e-23, 6.14248693e-23]), array([   0,    1,    2, ..., 2498, 2499, 2500])])

# %%
ll = cls['ell'][2:]
clTT = cls['tt'][2:]
clEE = cls['ee'][2:]
clPP = cls['pp'][2:]

# %%
# uncomment to get plots displayed in notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from math import pi

# %%
# plot C_l^TT
plt.figure(1)
plt.xscale('log');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll,clTT*ll*(ll+1)/2./pi,'r-')

# %%
plt.savefig('warmup_cltt.pdf')

# %%
# get P(k) at redhsift z=0
import numpy as np
kk = np.logspace(-4,np.log10(3),1000) # k in h/Mpc
Pk = [] # P(k) in (Mpc/h)**3
h = LambdaCDM.h() # get reduced Hubble for conversions to 1/Mpc
for k in kk:
    Pk.append(LambdaCDM.pk(k*h,0.)*h**3) # function .pk(k,z)

# %%
# create instance of the class "Class"
LambdaCDM1 = Class()
# pass input parameters
LambdaCDM1.set({'omega_b':0.022032,'omega_cdm':0.12038,'h':0.67556,'A_s':2.215e-9,'n_s':0.9619,'tau_reio':0.0925})
LambdaCDM1.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
# run class
LambdaCDM1.compute()

# %%
# get P(k) at redhsift z=0
import numpy as np
kk = np.logspace(-4,np.log10(3),1000) # k in h/Mpc
Pk1 = [] # P(k) in (Mpc/h)**3
h1 = LambdaCDM1.h() # get reduced Hubble for conversions to 1/Mpc
for k in kk:
    Pk1.append(LambdaCDM1.pk(k*h1,0.)*h**3) # function .pk(k,z)

# %%
# plot P(k)
plt.figure(2)
plt.xscale('log');plt.yscale('log');plt.xlim(kk[0],kk[-1])
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk,Pk,'b-', label="exponencial")
plt.plot(kk,Pk1,color='black',label=r"$\Lambda$CDM")
plt.legend()

# %%
plt.savefig('warmup_pk.pdf')

# %%
# optional: clear content of LambdaCDM (to reuse it for another model)
LambdaCDM.struct_cleanup()
# optional: reset parameters to default
LambdaCDM.empty()
